# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.59.tar.gz (25 kB)
# Requirement already satisfied: pandas>=0.24 in c:\users\alimi\anaconda3\lib\site-packages (from yfinance) (1.1.3)
# Requirement already satisfied: numpy>=1.15 in c:\users\alimi\anaconda3\lib\site-packages (from yfinance) (1.19.2)
# Requirement already satisfied: requests>=2.20 in c:\users\alimi\anaconda3\lib\site-packages (from yfinance) (2.24.0)
# Collecting multitasking>=0.0.7
#   Using cached multitasking-0.0.9.tar.gz (8.1 kB)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\alimi\anaconda3\lib\site-packages (from yfinance) (4.6.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\alimi\anaconda3\lib\site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\alimi\anaconda3\lib\site-packages (from pandas>=0.24->yfinance) (2020.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alimi\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\alimi\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\alimi\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\alimi\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (1.25.11)
# Requirement already satisfied: six>=1.5 in c:\users\alimi\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Building wheels for collected packages: yfinance, multitasking
#   Building wheel for yfinance (setup.py): started
#   Building wheel for yfinance (setup.py): finished with status 'done'
#   Created wheel for yfinance: filename=yfinance-0.1.59-py2.py3-none-any.whl size=23447 sha256=4b5d937b302949b7682e16ceb2a608036a256204b02f6696a368989741b91719
#   Stored in directory: c:\users\alimi\appdata\local\pip\cache\wheels\7e\d5\f4\f628965651f61ae35c2bdc73571ce1a2026e1550a336b5ad4b
#   Building wheel for multitasking (setup.py): started
#   Building wheel for multitasking (setup.py): finished with status 'done'
#   Created wheel for multitasking: filename=multitasking-0.0.9-py3-none-any.whl size=8372 sha256=62c0940f94b3cd47f7b3c86d6b7417233876ba2cd0b4180b03fd686619aa856d
#   Stored in directory: c:\users\alimi\appdata\local\pip\cache\wheels\57\6d\a3\a39b839cc75274d2acfb1c58bfead2f726c6577fe8c4723f13
# Successfully built yfinance multitasking
# Installing collected packages: multitasking, yfinance
# Successfully installed multitasking-0.0.9 yfinance-0.1.59

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# Yahoo Finance API for Python to provide live cryptocurrency data with less then a second lag

# %%
cur = ['BTC-USD','ETH','USDT-USD','XRP-USD','BCH','LTC','VTC']

data = yf.download(tickers=cur, period='22h', interval='5m')

# Yahoo Finance API arguments: Tickers || Start Date + End Date || Interval
#period - 22 last hours (argument_2)
#interval = interval of 5 minutes (argument_3)
# Out:
# [*********************100%***********************]  7 of 7 completed

# %%
data.head(2)
# Out:
#                            Adj Close                                         \
#                                  BCH BTC-USD        ETH        LTC USDT-USD
# Datetime
# 2021-04-08 16:00:00+00:00  23.480000     NaN  27.110001  43.540001      NaN
# 2021-04-08 16:05:00+00:00  23.459999     NaN  27.110001  43.560001      NaN
#
#                                                   Close                     \
#                                  VTC XRP-USD        BCH BTC-USD        ETH
# Datetime
# 2021-04-08 16:00:00+00:00        NaN     NaN  23.480000     NaN  27.110001
# 2021-04-08 16:05:00+00:00  89.970001     NaN  23.459999     NaN  27.110001
#
#                            ...     Open                     Volume          \
#                            ... USDT-USD        VTC XRP-USD     BCH BTC-USD
# Datetime                   ...
# 2021-04-08 16:00:00+00:00  ...      NaN        NaN     NaN     0.0     NaN
# 2021-04-08 16:05:00+00:00  ...      NaN  89.970001     NaN  2250.0     NaN
#
#
#                               ETH     LTC USDT-USD  VTC XRP-USD
# Datetime
# 2021-04-08 16:00:00+00:00     0.0     0.0      NaN  NaN     NaN
# 2021-04-08 16:05:00+00:00  2800.0  1097.0      NaN  0.0     NaN
#
# [2 rows x 42 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 254 entries, 2021-04-13 11:25:00+01:00 to 2021-04-14 08:28:02+01:00
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Adj Close, BCH-USDT)  0 non-null      float64
#  1   (Adj Close, BTC-USD)   254 non-null    float64
#  2   (Adj Close, ETH-USD)   254 non-null    float64
#  3   (Adj Close, LTC-USD)   254 non-null    float64
#  4   (Adj Close, USDT-USD)  253 non-null    float64
#  5   (Adj Close, VTC-USD)   253 non-null    float64
#  6   (Adj Close, XRP-USD)   254 non-null    float64
#  7   (Close, BCH-USDT)      0 non-null      float64
#  8   (Close, BTC-USD)       254 non-null    float64
#  9   (Close, ETH-USD)       254 non-null    float64
#  10  (Close, LTC-USD)       254 non-null    float64
#  11  (Close, USDT-USD)      253 non-null    float64
#  12  (Close, VTC-USD)       253 non-null    float64
#  13  (Close, XRP-USD)       254 non-null    float64
#  14  (High, BCH-USDT)       0 non-null      float64
#  15  (High, BTC-USD)        254 non-null    float64
#  16  (High, ETH-USD)        254 non-null    float64
#  17  (High, LTC-USD)        254 non-null    float64
#  18  (High, USDT-USD)       253 non-null    float64
#  19  (High, VTC-USD)        253 non-null    float64
#  20  (High, XRP-USD)        254 non-null    float64
#  21  (Low, BCH-USDT)        0 non-null      float64
#  22  (Low, BTC-USD)         254 non-null    float64
#  23  (Low, ETH-USD)         254 non-null    float64
#  24  (Low, LTC-USD)         254 non-null    float64
#  25  (Low, USDT-USD)        253 non-null    float64
#  26  (Low, VTC-USD)         253 non-null    float64
#  27  (Low, XRP-USD)         254 non-null    float64
#  28  (Open, BCH-USDT)       0 non-null      float64
#  29  (Open, BTC-USD)        254 non-null    float64
#  30  (Open, ETH-USD)        254 non-null    float64
#  31  (Open, LTC-USD)        254 non-null    float64
#  32  (Open, USDT-USD)       253 non-null    float64
#  33  (Open, VTC-USD)        253 non-null    float64
#  34  (Open, XRP-USD)        254 non-null    float64
#  35  (Volume, BCH-USDT)     0 non-null      float64
#  36  (Volume, BTC-USD)      254 non-null    int64
#  37  (Volume, ETH-USD)      254 non-null    int64
#  38  (Volume, LTC-USD)      254 non-null    int64
#  39  (Volume, USDT-USD)     253 non-null    float64
#  40  (Volume, VTC-USD)      253 non-null    float64
#  41  (Volume, XRP-USD)      254 non-null    int64
# dtypes: float64(38), int64(4)
# memory usage: 85.3 KB

# %%
data.isnull().value_counts().sum()
# Out:
# 475

# %%
import seaborn as sns
sns.heatmap(data.isnull(), cmap='viridis')
# Out:
# <AxesSubplot:xlabel='None-None', ylabel='Datetime'>

# %%
data.head()
# Out:
#                            Adj Close                                         \
#                                  BCH BTC-USD        ETH        LTC USDT-USD
# Datetime
# 2021-04-08 16:00:00+00:00  23.480000     NaN  27.110001  43.540001      NaN
# 2021-04-08 16:05:00+00:00  23.459999     NaN  27.110001  43.560001      NaN
# 2021-04-08 16:10:00+00:00  23.480000     NaN  27.110001  43.511299      NaN
# 2021-04-08 16:15:00+00:00        NaN     NaN  27.139999  43.649799      NaN
# 2021-04-08 16:20:00+00:00  23.510000     NaN  27.110001  43.680000      NaN
#
#                                                   Close                     \
#                                  VTC XRP-USD        BCH BTC-USD        ETH
# Datetime
# 2021-04-08 16:00:00+00:00        NaN     NaN  23.480000     NaN  27.110001
# 2021-04-08 16:05:00+00:00  89.970001     NaN  23.459999     NaN  27.110001
# 2021-04-08 16:10:00+00:00  89.985001     NaN  23.480000     NaN  27.110001
# 2021-04-08 16:15:00+00:00  90.000000     NaN        NaN     NaN  27.139999
# 2021-04-08 16:20:00+00:00        NaN     NaN  23.510000     NaN  27.110001
#
#                            ...     Open                     Volume          \
#                            ... USDT-USD        VTC XRP-USD     BCH BTC-USD
# Datetime                   ...
# 2021-04-08 16:00:00+00:00  ...      NaN        NaN     NaN     0.0     NaN
# 2021-04-08 16:05:00+00:00  ...      NaN  89.970001     NaN  2250.0     NaN
# 2021-04-08 16:10:00+00:00  ...      NaN  89.985001     NaN   168.0     NaN
# 2021-04-08 16:15:00+00:00  ...      NaN  90.000000     NaN     NaN     NaN
# 2021-04-08 16:20:00+00:00  ...      NaN        NaN     NaN   282.0     NaN
#
#
#                               ETH     LTC USDT-USD     VTC XRP-USD
# Datetime
# 2021-04-08 16:00:00+00:00     0.0     0.0      NaN     NaN     NaN
# 2021-04-08 16:05:00+00:00  2800.0  1097.0      NaN     0.0     NaN
# 2021-04-08 16:10:00+00:00  2652.0  1091.0      NaN  1130.0     NaN
# 2021-04-08 16:15:00+00:00  3231.0  1840.0      NaN   294.0     NaN
# 2021-04-08 16:20:00+00:00  3543.0   455.0      NaN     NaN     NaN
#
# [5 rows x 42 columns]

# %%
# dataframe to be stored in CSV file
data.to_csv('livecryptocurrencydata.csv')
